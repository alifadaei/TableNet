# %%
from modules import TableImage
import cv2

# %%
# setup part
image = TableImage(IMG = cv2.imread('test3.jpg'), N = 35)

# %%
# so the plot clearly shows that the summits tend to be the comlumns and the valley are less expected to be columns so this is the
# probability function of x where x is the distance from left side of image
# now we must be able to determine the value of N for diffent images in size and resolution and font size
# and find the exact teretories of columns like (x0 to x1)

# %%
image.printfn(showImage=True, showSegments=False, showDensities = True, showColumns=True)
